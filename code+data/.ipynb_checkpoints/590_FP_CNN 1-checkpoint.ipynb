# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_files
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import array_to_img, img_to_array, load_img
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D
from keras.layers import Activation, Dense, Flatten, Dropout
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras import backend as K

# %%
# processing train and test data from data files
train_data='fruits5/train'
test_data='fruits5/test'

def get_data(path):
    data = load_files(path)
    files = np.array(data['filenames'])
    targets = np.array(data['target'])
    target_labels = np.array(data['target_names'])
    return files,targets,target_labels

X_train, Y_train, labels = get_data(train_data)
X_test, Y_test,_ = get_data(test_data)

# %%
Y_train = np_utils.to_categorical(Y_train, 120)
Y_test = np_utils.to_categorical(Y_test, 120)

# %%
# splitting train set into train and validation set
X_train, X_val = train_test_split(X_train, test_size=0.2, random_state=33)
Y_train, Y_val = train_test_split(Y_train, test_size=0.2, random_state=33)

# %%
def convert_image_to_array(files):
    images_as_array=[]
    for file in files:
        images_as_array.append(img_to_array(load_img(file)))
    return images_as_array

X_train = np.array(convert_image_to_array(X_train))
X_val = np.array(convert_image_to_array(X_val))
X_test = np.array(convert_image_to_array(X_test))

# %%
X_train = X_train.astype('float32')/255
X_val = X_val.astype('float32')/255
X_test = X_test.astype('float32')/255

# %%
# specifying parameters for each convolutional layer
model = Sequential()

model.add(Conv2D(filters = 16, kernel_size = 2,input_shape=(100,100,3),padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters = 32,kernel_size = 2,activation= 'relu',padding='same'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters = 64,kernel_size = 2,activation= 'relu',padding='same'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters = 128,kernel_size = 2,activation= 'relu',padding='same'))
model.add(MaxPooling2D(pool_size=2))

# specifying parameters for fully connected layer
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(150))
model.add(Activation('relu'))
model.add(Dropout(0.4))
model.add(Dense(120,activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 100, 100, 16)      208
# _________________________________________________________________
# activation_2 (Activation)    (None, 100, 100, 16)      0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 50, 50, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 50, 50, 32)        2080
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 25, 25, 64)        8256
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 12, 12, 128)       32896
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 150)               691350
# _________________________________________________________________
# activation_3 (Activation)    (None, 150)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 150)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 120)               18120
# =================================================================
# Total params: 752,910
# Trainable params: 752,910
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
# creating a file to save the trained CNN model 
checkpointer = ModelCheckpoint(filepath = 'cnn_from_scratch_fruits.hdf5', verbose = 1, save_best_only = True)

# running 
CNN_model = model.fit(X_train,Y_train,
        batch_size = 120,
        epochs=20,
        validation_data=(X_val, Y_val),
        callbacks = [checkpointer],
        verbose=2, shuffle=True)
# Out:
# Epoch 1/20
#
# Epoch 00001: val_loss improved from inf to 0.58752, saving model to cnn_from_scratch_fruits.hdf5
# 17/17 - 5s - loss: 1.8910 - accuracy: 0.4428 - val_loss: 0.5875 - val_accuracy: 0.7635
# Epoch 2/20
#
# Epoch 00002: val_loss improved from 0.58752 to 0.18927, saving model to cnn_from_scratch_fruits.hdf5
# 17/17 - 5s - loss: 0.6079 - accuracy: 0.7957 - val_loss: 0.1893 - val_accuracy: 0.9212
# Epoch 3/20
#
# Epoch 00003: val_loss improved from 0.18927 to 0.03677, saving model to cnn_from_scratch_fruits.hdf5
# 17/17 - 5s - loss: 0.2458 - accuracy: 0.9381 - val_loss: 0.0368 - val_accuracy: 1.0000
# Epoch 4/20
#
# Epoch 00004: val_loss improved from 0.03677 to 0.00556, saving model to cnn_from_scratch_fruits.hdf5
# 17/17 - 5s - loss: 0.0381 - accuracy: 0.9974 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 5/20
#
# Epoch 00005: val_loss improved from 0.00556 to 0.00510, saving model to cnn_from_scratch_fruits.hdf5
# 17/17 - 5s - loss: 0.1758 - accuracy: 0.9626 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 6/20
#
# Epoch 00006: val_loss improved from 0.00510 to 0.00144, saving model to cnn_from_scratch_fruits.hdf5
# 17/17 - 5s - loss: 0.0091 - accuracy: 0.9995 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 7/20
#
# Epoch 00007: val_loss did not improve from 0.00144
# 17/17 - 5s - loss: 0.2170 - accuracy: 0.9506 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 8/20
#
# Epoch 00008: val_loss improved from 0.00144 to 0.00058, saving model to cnn_from_scratch_fruits.hdf5
# 17/17 - 5s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 5.7853e-04 - val_accuracy: 1.0000
# Epoch 9/20
#
# Epoch 00009: val_loss improved from 0.00058 to 0.00019, saving model to cnn_from_scratch_fruits.hdf5
# 17/17 - 6s - loss: 0.0028 - accuracy: 0.9995 - val_loss: 1.9300e-04 - val_accuracy: 1.0000
# Epoch 10/20
#
# Epoch 00010: val_loss did not improve from 0.00019
# 17/17 - 5s - loss: 0.1030 - accuracy: 0.9844 - val_loss: 0.0432 - val_accuracy: 0.9876
# Epoch 11/20
#
# Epoch 00011: val_loss did not improve from 0.00019
# 17/17 - 5s - loss: 0.0131 - accuracy: 0.9969 - val_loss: 4.3793e-04 - val_accuracy: 1.0000
# Epoch 12/20
#
# Epoch 00012: val_loss improved from 0.00019 to 0.00017, saving model to cnn_from_scratch_fruits.hdf5
# 17/17 - 5s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.7079e-04 - val_accuracy: 1.0000
# Epoch 13/20
#
# Epoch 00013: val_loss improved from 0.00017 to 0.00009, saving model to cnn_from_scratch_fruits.hdf5
# 17/17 - 6s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 8.7543e-05 - val_accuracy: 1.0000
# Epoch 14/20
#
# Epoch 00014: val_loss improved from 0.00009 to 0.00004, saving model to cnn_from_scratch_fruits.hdf5
# 17/17 - 6s - loss: 5.2917e-04 - accuracy: 1.0000 - val_loss: 4.2934e-05 - val_accuracy: 1.0000
# Epoch 15/20
#
# Epoch 00015: val_loss did not improve from 0.00004
# 17/17 - 7s - loss: 0.2205 - accuracy: 0.9792 - val_loss: 3.3786e-04 - val_accuracy: 1.0000
# Epoch 16/20
#
# Epoch 00016: val_loss did not improve from 0.00004
# 17/17 - 6s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 7.4199e-05 - val_accuracy: 1.0000
# Epoch 17/20
#
# Epoch 00017: val_loss improved from 0.00004 to 0.00004, saving model to cnn_from_scratch_fruits.hdf5
# 17/17 - 6s - loss: 6.2381e-04 - accuracy: 1.0000 - val_loss: 3.6172e-05 - val_accuracy: 1.0000
# Epoch 18/20
#
# Epoch 00018: val_loss did not improve from 0.00004
# 17/17 - 6s - loss: 0.1424 - accuracy: 0.9802 - val_loss: 4.7731e-04 - val_accuracy: 1.0000
# Epoch 19/20
#
# Epoch 00019: val_loss did not improve from 0.00004
# 17/17 - 6s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.4360e-04 - val_accuracy: 1.0000
# Epoch 20/20
#
# Epoch 00020: val_loss did not improve from 0.00004
# 17/17 - 6s - loss: 6.7771e-04 - accuracy: 1.0000 - val_loss: 6.6077e-05 - val_accuracy: 1.0000

# %%
model.load_weights('cnn_from_scratch_fruits.hdf5')

# %%
score = model.evaluate(X_test, Y_test)
print('Test accuracy:', score[1])
# Out:
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0017 - accuracy: 1.0000
# Test accuracy: 1.0

# %%
# using model to predict on test data
Y_pred = model.predict(X_test)

# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 15))
for i, idx in enumerate(np.random.choice(X_test.shape[0], size=25, replace=False)):
    ax = fig.add_subplot(5, 5, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(X_test[idx]))
    pred_idx = np.argmax(Y_pred[idx])
    true_idx = np.argmax(Y_test[idx])
    ax.set_title("{} ({})".format(labels[pred_idx], labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))

# %%
# plotting model accuracy 
plt.figure(1, figsize = (10, 10))  
plt.subplot(211)  
plt.plot(CNN_model.history['accuracy'])  
plt.plot(CNN_model.history['val_accuracy'])  
plt.title('Model Accuracy')  
plt.ylabel('Accuracy')  
plt.xlabel('Epoch')  
plt.legend(['train', 'validation'], loc='upper left')   

# plotting model loss 
plt.subplot(212)  
plt.plot(CNN_model.history['loss'])  
plt.plot(CNN_model.history['val_loss'])  
plt.title('Model Loss')  
plt.ylabel('Loss')  
plt.xlabel('Epoch')  
plt.legend(['train', 'validation'], loc='upper left')  
plt.show()
