# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_files
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import array_to_img, img_to_array, load_img
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D
from keras.layers import Activation, Dense, Flatten, Dropout
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras import backend as K

# %% [markdown]
# # Data Preprocessing

# %%
train_data='fruits5/train'
test_data='fruits5/test'

def get_data(path):
    data = load_files(path)
    files = np.array(data['filenames'])
    targets = np.array(data['target'])
    target_labels = np.array(data['target_names'])
    return files,targets,target_labels

X_train, Y_train, labels = get_data(train_data)
X_test, Y_test,_ = get_data(test_data)


Y_train = np_utils.to_categorical(Y_train, 5)
Y_test = np_utils.to_categorical(Y_test, 5)

# %%
# splitting train set into train and validation set
X_train, X_val = train_test_split(X_train, test_size=0.2, random_state=33)
Y_train, Y_val = train_test_split(Y_train, test_size=0.2, random_state=33)

# %%
# convert_image_to_array
def convert_image_to_array(files):
    images_as_array=[]
    for file in files:
        images_as_array.append(img_to_array(load_img(file)))
    return images_as_array

X_train = np.array(convert_image_to_array(X_train))
X_val = np.array(convert_image_to_array(X_val))
X_test = np.array(convert_image_to_array(X_test))

# %%
#re-scale data to make all the pixel values within 0 to 1
X_train = X_train.astype('float32')/255
X_val = X_val.astype('float32')/255
X_test = X_test.astype('float32')/255

# %% [markdown]
# # CNN Model Building

# %%
# specifying parameters for each convolutional layer
model = Sequential()

model.add(Conv2D(filters = 16, kernel_size = 2,input_shape=(100,100,3),padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters = 32,kernel_size = 2,activation= 'relu',padding='same'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters = 64,kernel_size = 2,activation= 'relu',padding='same'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters = 128,kernel_size = 2,activation= 'relu',padding='same'))
model.add(MaxPooling2D(pool_size=2))

# specifying parameters for fully connected layer
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Activation('relu'))
model.add(Dropout(0.4))
model.add(Dense(5,activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 100, 100, 16)      208
# _________________________________________________________________
# activation_6 (Activation)    (None, 100, 100, 16)      0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 50, 50, 16)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 50, 50, 32)        2080
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 25, 25, 64)        8256
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 12, 12, 128)       32896
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# activation_7 (Activation)    (None, 4608)              0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 4608)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 23045
# =================================================================
# Total params: 66,485
# Trainable params: 66,485
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Compile Model

# %%
#data augmentation
datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1,  horizontal_flip=True)
it_gen = datagen.flow(X_train, Y_train, batch_size=256)

# %%
model.compile(loss='categorical_crossentropy',optimizer='rmsprop', metrics=['accuracy'])

# %%
# creating a file to save the trained CNN model 
checkpointer = ModelCheckpoint(filepath = 'cnn_from_scratch_fruits.hdf5', verbose = 1, save_best_only = True)

# %% [markdown]
# # Fitting Model

# %%
CNN_model = model.fit(it_gen,
        batch_size = 256,
        epochs=20,
        validation_data=(X_val, Y_val),
        callbacks = [checkpointer],
        verbose=2, shuffle=True)
# Out:
# Epoch 1/20
#
# Epoch 00001: val_loss improved from inf to 1.07916, saving model to cnn_from_scratch_fruits.hdf5
# 8/8 - 5s - loss: 1.4815 - accuracy: 0.3529 - val_loss: 1.0792 - val_accuracy: 0.6556
# Epoch 2/20
#
# Epoch 00002: val_loss did not improve from 1.07916
# 8/8 - 5s - loss: 1.0427 - accuracy: 0.6289 - val_loss: 1.3611 - val_accuracy: 0.3734
# Epoch 3/20
#
# Epoch 00003: val_loss improved from 1.07916 to 0.53650, saving model to cnn_from_scratch_fruits.hdf5
# 8/8 - 5s - loss: 0.7570 - accuracy: 0.7448 - val_loss: 0.5365 - val_accuracy: 0.7676
# Epoch 4/20
#
# Epoch 00004: val_loss improved from 0.53650 to 0.25043, saving model to cnn_from_scratch_fruits.hdf5
# 8/8 - 5s - loss: 0.5260 - accuracy: 0.8025 - val_loss: 0.2504 - val_accuracy: 0.9710
# Epoch 5/20
#
# Epoch 00005: val_loss improved from 0.25043 to 0.17461, saving model to cnn_from_scratch_fruits.hdf5
# 8/8 - 5s - loss: 0.3524 - accuracy: 0.8706 - val_loss: 0.1746 - val_accuracy: 0.9876
# Epoch 6/20
#
# Epoch 00006: val_loss improved from 0.17461 to 0.10433, saving model to cnn_from_scratch_fruits.hdf5
# 8/8 - 5s - loss: 0.3367 - accuracy: 0.9044 - val_loss: 0.1043 - val_accuracy: 0.9834
# Epoch 7/20
#
# Epoch 00007: val_loss improved from 0.10433 to 0.05952, saving model to cnn_from_scratch_fruits.hdf5
# 8/8 - 5s - loss: 0.2246 - accuracy: 0.9257 - val_loss: 0.0595 - val_accuracy: 0.9979
# Epoch 8/20
#
# Epoch 00008: val_loss did not improve from 0.05952
# 8/8 - 5s - loss: 0.1864 - accuracy: 0.9465 - val_loss: 0.3293 - val_accuracy: 0.8838
# Epoch 9/20
#
# Epoch 00009: val_loss improved from 0.05952 to 0.03183, saving model to cnn_from_scratch_fruits.hdf5
# 8/8 - 5s - loss: 0.1263 - accuracy: 0.9782 - val_loss: 0.0318 - val_accuracy: 0.9979
# Epoch 10/20
#
# Epoch 00010: val_loss did not improve from 0.03183
# 8/8 - 5s - loss: 0.0575 - accuracy: 0.9912 - val_loss: 0.1540 - val_accuracy: 0.9440
# Epoch 11/20
#
# Epoch 00011: val_loss improved from 0.03183 to 0.01842, saving model to cnn_from_scratch_fruits.hdf5
# 8/8 - 6s - loss: 0.2197 - accuracy: 0.9168 - val_loss: 0.0184 - val_accuracy: 1.0000
# Epoch 12/20
#
# Epoch 00012: val_loss improved from 0.01842 to 0.00989, saving model to cnn_from_scratch_fruits.hdf5
# 8/8 - 6s - loss: 0.0326 - accuracy: 0.9979 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 13/20
#
# Epoch 00013: val_loss improved from 0.00989 to 0.00546, saving model to cnn_from_scratch_fruits.hdf5
# 8/8 - 6s - loss: 0.0276 - accuracy: 0.9958 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 14/20
#
# Epoch 00014: val_loss did not improve from 0.00546
# 8/8 - 5s - loss: 0.3272 - accuracy: 0.9080 - val_loss: 0.0198 - val_accuracy: 1.0000
# Epoch 15/20
#
# Epoch 00015: val_loss did not improve from 0.00546
# 8/8 - 5s - loss: 0.0351 - accuracy: 0.9953 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 16/20
#
# Epoch 00016: val_loss improved from 0.00546 to 0.00545, saving model to cnn_from_scratch_fruits.hdf5
# 8/8 - 6s - loss: 0.0187 - accuracy: 0.9990 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 17/20
#
# Epoch 00017: val_loss improved from 0.00545 to 0.00297, saving model to cnn_from_scratch_fruits.hdf5
# 8/8 - 5s - loss: 0.0142 - accuracy: 0.9984 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 18/20
#
# Epoch 00018: val_loss did not improve from 0.00297
# 8/8 - 5s - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 19/20
#
# Epoch 00019: val_loss did not improve from 0.00297
# 8/8 - 5s - loss: 0.3487 - accuracy: 0.9148 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 20/20
#
# Epoch 00020: val_loss did not improve from 0.00297
# 8/8 - 5s - loss: 0.0168 - accuracy: 0.9984 - val_loss: 0.0043 - val_accuracy: 1.0000

# %%
model.load_weights('cnn_from_scratch_fruits.hdf5')

# %%
score = model.evaluate(X_test, Y_test)
print('Test accuracy:', score[1])
# Out:
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0285 - accuracy: 0.9876
# Test accuracy: 0.9876237511634827

# %% [markdown]
# # Prediction and Plots

# %%
# plotting model accuracy 
plt.figure(1, figsize = (10, 10))  
plt.subplot(211)  
plt.plot(CNN_model.history['accuracy'])  
plt.plot(CNN_model.history['val_accuracy'])  
plt.title('Model Accuracy')  
plt.ylabel('Accuracy')  
plt.xlabel('Epoch')  
plt.legend(['train', 'validation'], loc='upper left')   

# plotting model loss 
plt.subplot(212)  
plt.plot(CNN_model.history['loss'])  
plt.plot(CNN_model.history['val_loss'])  
plt.title('Model Loss')  
plt.ylabel('Loss')  
plt.xlabel('Epoch')  
plt.legend(['train', 'validation'], loc='upper left')  
plt.show()

# %%
# predict on test data
Y_pred = model.predict(X_test)

# plot predicted data and their class
fig = plt.figure(figsize=(20, 15))
for i, idx in enumerate(np.random.choice(X_test.shape[0], size=25, replace=False)):
    ax = fig.add_subplot(5, 5, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(X_test[idx]))
    pred_idx = np.argmax(Y_pred[idx])
    true_idx = np.argmax(Y_test[idx])
    ax.set_title("{} ({})".format(labels[pred_idx], labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
